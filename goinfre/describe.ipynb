# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../datasets/dataset_train.csv", index_col = "Index")

# %%
df2 = df.select_dtypes(include=['int64','float64'])

# %%
df2
# Out:
#        Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# Index
# 0         58384.0 -487.886086   5.727180                       4.878861
# 1         67239.0 -552.060507  -5.987446                       5.520605
# 2         23702.0 -366.076117   7.725017                       3.660761
# 3         32667.0  697.742809  -6.497214                      -6.977428
# 4         60158.0  436.775204  -7.820623                            NaN
# ...           ...         ...        ...                            ...
# 1595      49009.0  354.280086  -4.541837                      -3.542801
# 1596      63296.0  367.531174   6.061064                      -3.675312
# 1597      63905.0  544.018925  -3.203269                      -5.440189
# 1598      82713.0  453.676219   3.442831                      -4.536762
# 1599      48639.0  688.911989   5.421046                      -6.889120
#
#        Divination  Muggle Studies  Ancient Runes  History of Magic  \
# Index
# ...

# %%
stats = df.loc[:0,'Arithmancy':]

# %%
stats = pd.DataFrame(columns=df.loc[:0,'Arithmancy':].columns)

# %%
nb_col = len(stats.columns)

# %%
nb_col
# Out:
# 13

# %%
# Pour les stats, la partie House, nom et prenom ne sert a rien. 
# Il vaut peut etre mieux aussi transformer les dates de naissances par des ages au moment. 
# Best hand ne veux rien dire non plus pour des mean.

# %%
col_name=stats.columns

# %%
for i in range (nb_col):
	col = df.loc[:, col_name[i]]
	col_allNum = df.loc[~col.isna(), col_name[i]]
	count = len(col_allNum)
	mean = sum(col_allNum) / len(col_allNum)
	var =  sum([(x - mean)**2 for x in col_allNum])/count
	std = var**(0.5)
	quartile25 = float(sorted(col_allNum)[int(count/4)])
	quartile50 = float(sorted(col_allNum)[int(count/2)])
	quartile75 = float(sorted(col_allNum)[int(3 * count/4)])
	maxval = sorted(col_allNum)[count - 1]
	minval = sorted(col_allNum)[0]
	stats.loc['Count', col_name[i]] = count
	stats.loc['Mean', col_name[i]] = mean
	stats.loc['Std', col_name[i]] = std
	stats.loc['Min', col_name[i]] = minval
	stats.loc['25%', col_name[i]] = quartile25
	stats.loc['50%', col_name[i]] = quartile50
	stats.loc['75%', col_name[i]] = quartile75
	stats.loc['Max', col_name[i]] = maxval

# %%
stats
# Out:
#          Arithmancy   Astronomy  Herbology Defense Against the Dark Arts  \
# Count          1566        1568       1567                          1569
# Mean   49634.570243   39.797131    1.14102                     -0.387863
# Std    16674.479577   520.13233   5.218016                      5.211132
# Min        -24370.0 -966.740546 -10.295663                    -10.162119
# 25%         38510.0 -489.493777  -4.312118                     -5.259095
# 50%         49018.0  261.644731   3.469012                     -2.589342
# 75%         60828.0   525.90954   5.421046                       4.90468
# Max        104956.0  1016.21194  11.612895                      9.667405
#
#       Divination Muggle Studies Ancient Runes History of Magic  \
# Count       1561           1565          1565             1557
# Mean     3.15391    -224.589915     495.74797         2.963095
# Std      4.15397     486.189433    106.251202         4.424353
# ...

# %%
def describe(path):
    df = pd.read_csv(path, index_col = "Index")
    dfNum = df.select_dtypes(include=['int64','float64'], exclude=[])
    cols_vides = [col for col in dfNum.columns if dfNum[col].isna().all()]
    dfNum.drop(cols_vides, axis=1, inplace=True)
    stats = pd.DataFrame(columns=dfNum.columns)
    col_name=stats.columns
    for i in range (len(stats.columns)):
        col = dfNum.loc[:, col_name[i]]
        col_allNum = dfNum.loc[~col.isna(), col_name[i]]
        count = len(col_allNum)
        mean = sum(col_allNum) / len(col_allNum)
        var =  sum([(x - mean)**2 for x in col_allNum])/count
        std = var**(0.5)
        quartile25 = float(sorted(col_allNum)[int(count/4)])
        quartile50 = float(sorted(col_allNum)[int(count/2)])
        quartile75 = float(sorted(col_allNum)[int(3 * count/4)])
        maxval = sorted(col_allNum)[count - 1]
        minval = sorted(col_allNum)[0]
        stats.loc['Count', col_name[i]] = count
        stats.loc['Mean', col_name[i]] = mean
        stats.loc['Std', col_name[i]] = std
        stats.loc['Min', col_name[i]] = minval
        stats.loc['25%', col_name[i]] = quartile25
        stats.loc['50%', col_name[i]] = quartile50
        stats.loc['75%', col_name[i]] = quartile75
        stats.loc['Max', col_name[i]] = maxval
    # print(stats)
    return stats

# %%
result_train = describe("datasets/dataset_train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 result_train = describe("datasets/dataset_train.csv")
#
# Cell In[13], line 2, in describe(path)
#       1 def describe(path):
# ----> 2     df = pd.read_csv(path, index_col = "Index")
#       3     dfNum = df.select_dtypes(include=['int64','float64'], exclude=[])
#       4     cols_vides = [col for col in dfNum.columns if dfNum[col].isna().all()]
#
# ...

# %%
result_train
# Out:
#          Arithmancy   Astronomy  Herbology Defense Against the Dark Arts  \
# Count          1566        1568       1567                          1569
# Mean   49634.570243   39.797131    1.14102                     -0.387863
# Std    16674.479577   520.13233   5.218016                      5.211132
# Min        -24370.0 -966.740546 -10.295663                    -10.162119
# 25%         38510.0 -489.493777  -4.312118                     -5.259095
# 50%         49018.0  261.644731   3.469012                     -2.589342
# 75%         60828.0   525.90954   5.421046                       4.90468
# Max        104956.0  1016.21194  11.612895                      9.667405
#
#       Divination Muggle Studies Ancient Runes History of Magic  \
# Count       1561           1565          1565             1557
# Mean     3.15391    -224.589915     495.74797         2.963095
# Std      4.15397     486.189433    106.251202         4.424353
# ...

# %%
result_test = describe("datasets/dataset_test.csv")

# %%
result_test
# Out:
#          Arithmancy   Astronomy Herbology Defense Against the Dark Arts  \
# Count           387         387       389                           392
# Mean   50088.971576   48.155326  1.385517                     -0.537843
# Std    15452.744803  511.875159  5.048793                      5.112229
# Min          4536.0  -802.72518 -9.687662                     -8.700635
# 25%         40142.0 -485.300284 -4.183731                     -5.205897
# 50%         49238.0  292.108738   3.63049                      -2.91022
# 75%         60182.0  511.393084  5.405685                      4.785424
# Max         99744.0  870.063498  9.678462                      8.027252
#
#       Divination Muggle Studies Ancient Runes History of Magic  \
# Count        394            390           392              389
# Mean    3.411071    -220.169594    495.937543         2.829816
# Std      3.88625     497.030335     101.52767         4.311657
# Min       -8.183   -1041.323658     319.36025         -7.18909
# ...
